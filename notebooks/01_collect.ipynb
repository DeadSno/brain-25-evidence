# %%
# ── ОБНОВЛЕНИЕ ДАННЫХ (сеть, ~2–3 мин). Обычно ПРОПУСКАЙ: ──
# df_pubmed = parsers.collect_pubmed()
# df_pubmed = parsers.collect_openalex(df_pubmed)
# df_pubmed.to_csv(RAW / "pubmed_evidence.csv", index=False, encoding="utf-8-sig")
# wb_new = parsers.collect_wb_prices()
# wb_new.to_excel(RAW / "prices_wb_new.xlsx", index=False)
print("Сбор пропущен: актуальные данные уже лежат в data/raw")
# Out:
# Сбор пропущен: актуальные данные уже лежат в data/raw
